# %%
a = int(input("Enter a x co-ordinate"))
b = int(input("Enter a Y co-ordinate"))
if a>0 and b>0:
    print("The point lies in the First Quadrant")
elif a<0 and b>0:
    print("The point lies in the Second Quadrant")
elif a<0 and b<0:
    print("The point lies in the Third Quadrant")
elif a>0 and b<0:
    print("The point lies in the Fourth Quadrant")
else:
    print("The point lies on the Axis ")
# Out:
# The point lies on the Axis

# %%
a=input("Enter a color:").lower()
if a=="red":
    print("Stop the car.")
elif a=="yellow":
    print("Get ready.")
elif a=="green":
    print("Go.")
else:
    print("Invalid color.")
# Out:
# Invalid color.

# %%
a=int(input("Enter a number:"))
if a<0 and a%10==5:
    print("Negative Number")
elif (a%10==5):
    print("Valid Number")   
else:
    print("Invalid Number")
# Out:
# Invalid Number

# %%
a=int(input("Enter a percentage"))
if a>=90:
    print("A+")
elif a>=80:
    print("A")
elif a>=70:
    print("B")
elif a>=35:
    print("c")
else:
    print("Fail")
# Out:
# c

# %%
b=input("Enter a username:")
c=input("Enter a password:")
if (b=="admin") and (c=="1234"):
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Login Failed
